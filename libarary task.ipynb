# %%
borrwoed_books=[]
available_books=[]
memmbers=[]
while True:
    print("1-view all books")
    print("2-add a new book")
    print("3-Register a new member")
    print("4-borrow book")
    print("5-retern book")
    print("6-random book suggestion")
    print("7-show libarary statistics")
    print("8- for finish and exist")
    choice1 = input("plz , enter the number of your opp: ")
    if choice1=='1':
        print(f"available books : {available_books}")
        print(f"borrowed books : {borrwoed_books}")
    elif choice1 == '2':
        book_name = input("enter the name of a new book :")
        available_books.append(book_name)
        print("the book was added")
    elif choice1 == '3':
        mem_name = input("enter the name of new memmber")
        memmbers.append(mem_name)
        print("memmber regrister .")
    elif choice1 == '4':
        book_name = input("wich book you want ? ")
        if book_name in available_books:
            available_books.remove(book_name)
            borrwoed_books.append(book_name)
        else:
            print("this book has been borrowed. \n chooce anther available book ")
    elif choice1 == '5':
        book_name = input("wich book are you returning ?")
        if book_name in borrwoed_books:
            borrwoed_books.remove(book_name)
            available_books.append(book_name)
            print("thanks, for returning this book.")
        else:
            print(f"{book_name} already is availabale ")
    elif choice1 == '6':
        import random
        random_book= random.choice(available_books)
        print(random_book)
    elif choice1 == '7':
        total = len(available_books) +len(borrwoed_books)
        print(f"number of all books in system = {total} \n number of borrowed books ={len(borrwoed_books)} \n number of availabel books = {len(available_books)}")
    elif choice1 == '8':
        print("thanks, for visit our libarary \n goodbye" )
        break
    else:
        print("chooce option from 1 to 8 ")
# Out:
# 1-view all books
# 2-add a new book
# 3-Register a new member
# 4-borrow book
# 5-retern book
# 6-random book suggestion
# 7-show libarary statistics
# 8- for finish and exist
# the book was added
# 1-view all books
# 2-add a new book
# 3-Register a new member
# 4-borrow book
# 5-retern book
# 6-random book suggestion
# 7-show libarary statistics
# 8- for finish and exist
# the book was added
# 1-view all books
# 2-add a new book
# 3-Register a new member
# 4-borrow book
# 5-retern book
# 6-random book suggestion
# 7-show libarary statistics
# 8- for finish and exist
# the book was added
# 1-view all books
# 2-add a new book
# 3-Register a new member
# 4-borrow book
# 5-retern book
# 6-random book suggestion
# 7-show libarary statistics
# 8- for finish and exist
# رحلتي من الشك الي الايمان
# 1-view all books
# 2-add a new book
# 3-Register a new member
# 4-borrow book
# 5-retern book
# 6-random book suggestion
# 7-show libarary statistics
# 8- for finish and exist
